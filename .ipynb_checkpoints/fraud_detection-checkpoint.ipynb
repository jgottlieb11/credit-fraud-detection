# %% [markdown]
# ## INTRODUCTION
#     This project is based on the analysis of fraud detection using a variety of machine learning models, inspired by work done by Yazan Obeidi in his GitHub repository. The data used in this project is the Kaggle Credit Card Fraud Detection dataset. The dataset contains transactions made by European cardholders in September 2013 and consists of 284,807 transactions. Of these, only 492 transactions are labeled as fraudulent, making this a highly imbalanced dataset. In this notebook, several machine learning models are applied to detect fraud, and techniques like ADASYN are used to address class imbalance. The models evaluated in this project include K-Nearest Neighbors (KNN), Support Vector Machines (SVM), Random Forest (RF), and Multi-Layer Perceptrons (MLP).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import (
    confusion_matrix, classification_report, 
    auc, precision_recall_curve, roc_curve
)
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle

import pickle
from collections import Counter
import matplotlib.gridspec as gridspec

from sklearn.neighbors import KNeighborsClassifier

print("Loading dataset...")
data = pd.read_csv("data/creditcard.csv")
print("Dataset loaded successfully!")
# Out:
# Loading dataset...
# Dataset loaded successfully!

# %% [markdown]
# ## 2. Exploratory Data Analysis
# Exploratory Data Analysis helps to understand the underlying structure and distribution of the dataset. Here, we'll visualize the distribution of the key features, particularly focusing on transaction amounts, PCA-transformed features, and class balance (fraud vs. legitimate transactions).

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# Visualize the 28 PCA columns using subplots for clarity
fig, axes = plt.subplots(7, 4, figsize=(14, 10), sharex=True)
axes = axes.flatten()

for i in range(1, 29):
    sns.lineplot(data=data, x=data.index, y=f'V{i}', ax=axes[i-1])
    axes[i-1].set_title(f"V{i}", fontsize=10)
    
plt.tight_layout()
plt.show()

# %%
data.Class.value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# Displaying Class Distribution with a bar plot
class_counts = data['Class'].value_counts()
plt.figure(figsize=(6, 4))
sns.barplot(x=class_counts.index, y=class_counts.values)
plt.title("Class Distribution (Fraud vs Normal)")
plt.xlabel("Class")
plt.ylabel("Count")
plt.xticks([0, 1], ["Normal", "Fraud"])
plt.show()

# %%
# Seaborn KDE (Kernel Density Estimate) plot for time distribution
fig, ax = plt.subplots(figsize=(10, 6))
sns.kdeplot(data=data[data['Class'] == 1], x="Time", fill=True, label='Fraud', color='r', alpha=0.5)
sns.kdeplot(data=data[data['Class'] == 0], x="Time", fill=True, label='Normal', color='b', alpha=0.5)
plt.title("KDE Plot of Time for Fraud and Normal Transactions")
plt.xlabel("Time (seconds)")
plt.legend()
plt.show()

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(14,6), gridspec_kw={'hspace': 0.5})
ax1.hist(data.Amount[data.Class == 1], bins=40, color='red', edgecolor='black', alpha=0.7)
ax1.set_title('Fraudulent Transactions', fontsize=12)
ax2.hist(data.Amount[data.Class == 0], bins=40, color='green', edgecolor='black', alpha=0.7)
ax2.set_title('Legitimate Transactions', fontsize=12)
plt.xlabel('Transaction Amount ($)', fontsize=10)
plt.ylabel('Transaction Count', fontsize=10)
ax1.set_yscale('log')
ax2.set_yscale('log')
plt.show()

# %%
plt.figure(figsize=(12, 28*4))
gs = gridspec.GridSpec(28, 1)
for i in range(1, 29):
    ax = plt.subplot(gs[i-1])
    sns.histplot(data['V'+str(i)][data.Class == 1], bins=50, color='r', kde=True, stat="density", ax=ax)
    sns.histplot(data['V'+str(i)][data.Class == 0], bins=50, color='b', kde=True, stat="density", ax=ax)
    ax.set_xlabel('')
    ax.set_title('Histogram of feature: ' + 'V'+str(i))
plt.show()

# %% [markdown]
# ## 3. Data Preparation
# The dataset needs to be preprocessed for effective model training. This includes:
# - Dropping unnecessary columns.
# - Handling class imbalance using the ADASYN resampling technique.
# - Normalizing feature values.
# We also split the dataset into training, testing, and validation sets for both the original and resampled datasets.

# %%
# Drop unnecessary features from the dataset
clean_data = data.drop(columns=['V28', 'V27', 'V23', 'V8'], inplace=False)
print("Columns removed: V28, V27, V23, V8")
# Out:
# Columns removed: V28, V27, V23, V8

# %%
# Create dataframes of only Fraud and Normal transactions, then shuffle them
fraud = shuffle(data[data.Class == 1], random_state=42)
normal = shuffle(data[data.Class == 0], random_state=42)

# Produce a training set consisting of 80% of fraud and 80% of normal transactions
X_train = pd.concat([fraud.sample(frac=0.8, random_state=42), normal.sample(frac=0.8, random_state=42)], axis=0)

# Split the remainder into testing and validation sets
remainder = data.loc[~data.index.isin(X_train.index)]
X_test = remainder.sample(frac=0.7, random_state=42)
X_validation = remainder.loc[~remainder.index.isin(X_test.index)]

# %%
# Load the previously resampled training data from pickle files
with open('pickle/train_data_resampled.pkl', 'rb') as f:
    X_train_resampled = pickle.load(f)
with open('pickle/train_data_labels_resampled.pkl', 'rb') as f:
    X_train_labels_resampled = pickle.load(f)

# Print the class balance in the resampled data
print(Counter(X_train_labels_resampled))

# Combine resampled features and labels into a single dataframe
X_train_resampled = pd.DataFrame(X_train_resampled)
X_train_labels_resampled = pd.DataFrame(X_train_labels_resampled)
X_train_resampled = pd.concat([X_train_resampled, X_train_labels_resampled], axis=1)
X_train_resampled.columns = X_train.columns  # Ensure the columns match the original training data
X_train_resampled.head()
# Out:
# Counter({np.int64(1): 227480, np.int64(0): 227452})
#        Time         V1         V2         V3        V4         V5        V6  \
# 0   28692.0 -29.200329  16.155701 -30.013712  6.476731 -21.225810 -4.902997
# 1  102480.0  -1.929597   4.066413  -4.865184  5.898602  -0.552493 -1.555962
# 2   59669.0   0.326007   1.286638  -2.007181  2.419675  -1.532902 -1.432803
# 3   17838.0  -5.187878   6.967709 -13.510931  8.617895 -11.214422  0.672248
# 4   93860.0 -10.632375   7.251936 -17.681072  8.204144 -10.166591 -4.510344
#
#           V7         V8        V9  ...       V21       V22       V23  \
# 0 -19.791248  19.168327 -3.617242  ...  1.809371 -2.175815 -1.365104
# 1  -3.833623   0.679512 -3.463765  ...  1.137212  0.674245 -0.531765
# 2  -2.459530   0.617738 -1.125861  ...  0.556895  0.169776 -0.174357
# 3  -9.462533   5.328704 -4.897006  ...  2.086083  0.760190  0.716806
# 4 -12.981606   6.783589 -4.659330  ...  2.715357  0.695603 -1.138122
#
#         V24       V25       V26       V27       V28  Amount  Class
# 0  0.174286  2.103868 -0.209944  1.278681  0.372393   99.99      1
# 1 -0.433409  0.378659  0.198107  0.869694  0.228048    0.00      1
# 2  0.308061  0.710996 -0.231030  0.580495  0.300984    6.27      1
# 3 -0.646743 -1.617043  0.172347  0.626647 -0.169726  766.36      1
# 4  0.459442  0.386337  0.522438 -1.416604 -0.488307  188.52      1
#
# [5 rows x 31 columns]

# %%
# Shuffle the original and resampled datasets
X_train, y_train = shuffle(X_train, X_train['Class'], random_state=42)
X_test, y_test = shuffle(X_test, X_test['Class'], random_state=42)
X_validation, y_validation = shuffle(X_validation, X_validation['Class'], random_state=42)

X_train_, y_train_ = shuffle(X_train_resampled, X_train_resampled['Class'], random_state=42)
X_test_, y_test_ = shuffle(X_test, X_test['Class'], random_state=42)
X_validation_, y_validation_ = shuffle(X_validation, X_validation['Class'], random_state=42)

# Remove the 'Class' column from feature sets to prepare them for modeling
X_train = X_train.drop('Class', axis=1)
X_test = X_test.drop('Class', axis=1)
X_validation = X_validation.drop('Class', axis=1)

X_train_ = X_train_.drop('Class', axis=1)
X_test_ = X_test_.drop('Class', axis=1)
X_validation_ = X_validation_.drop('Class', axis=1)

# %%
# Normalize the features for the original datasets (X_train, X_test, X_validation)
for feature in X_train.columns:
    mean, std = data[feature].mean(), data[feature].std()  # Use the original data here for mean and std
    X_train[feature] = (X_train[feature] - mean) / std
    X_test[feature] = (X_test[feature] - mean) / std
    X_validation[feature] = (X_validation[feature] - mean) / std

# Normalize the resampled data (X_train_, X_test_, X_validation_)
for feature in X_train_.columns:
    mean, std = X_train_resampled[feature].mean(), X_train_resampled[feature].std()  # Use X_train_resampled here
    X_train_[feature] = (X_train_[feature] - mean) / std
    X_test_[feature] = (X_test_[feature] - mean) / std
    X_validation_[feature] = (X_validation_[feature] - mean) / std

# %%
# Extract labels for each dataset
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)
y_validation = y_validation.reset_index(drop=True)

y_train_ = y_train_.reset_index(drop=True)
y_test_ = y_test_.reset_index(drop=True)
y_validation_ = y_validation_.reset_index(drop=True)

# %%
# Save all datasets to a pickle file
dataset = {
    'X_train': X_train, 'y_train': y_train,
    'X_train_': X_train_, 'y_train_': y_train_,
    'X_test': X_test, 'y_test': y_test,
    'X_test_': X_test_, 'y_test_': y_test_,
    'X_validation': X_validation, 'y_validation': y_validation,
    'X_validation_': X_validation_, 'y_validation_': y_validation_
}

with open('pickle/data_with_resample.pkl', 'wb') as f:
    pickle.dump(dataset, f)

# %%
from collections import Counter

# Assuming the labels are stored in y_train, y_train_, y_validation, y_validation_, y_test, y_test_

# Use Counter to print the distribution of classes in each label dataset
print("'y_train_'", Counter(y_train_))  # Print for resampled training data
print("'y_validation'", Counter(y_validation))  # Print for validation data
print("'y_test_'", Counter(y_test_))  # Print for resampled test data
print("'y_train'", Counter(y_train))  # Print for original training data
print("'y_validation_'", Counter(y_validation_))  # Print for resampled validation data
print("'y_test'", Counter(y_test))  # Print for original test data
# Out:
# 'y_train_' Counter({1: 227480, 0: 227452})
# 'y_validation' Counter({0: 17060, 1: 28})
# 'y_test_' Counter({0: 39803, 1: 70})
# 'y_train' Counter({0: 227452, 1: 394})
# 'y_validation_' Counter({0: 17060, 1: 28})
# 'y_test' Counter({0: 39803, 1: 70})

# %%
def plot_confusion_matrix(y_test, pred):
    
    y_test_legit = y_test.value_counts()[0]
    y_test_fraud = y_test.value_counts()[1]
    
    cfn_matrix = confusion_matrix(y_test, pred)
    cfn_norm_matrix = np.array([[1.0 / y_test_legit,1.0/y_test_legit],[1.0/y_test_fraud,1.0/y_test_fraud]])
    norm_cfn_matrix = cfn_matrix * cfn_norm_matrix

    fig = plt.figure(figsize=(12,5))
    ax = fig.add_subplot(1,2,1)
    sns.heatmap(cfn_matrix,cmap='coolwarm_r',linewidths=0.5,annot=True,ax=ax)
    plt.title('Confusion Matrix')
    plt.ylabel('Real Classes')
    plt.xlabel('Predicted Classes')

    ax = fig.add_subplot(1,2,2)
    sns.heatmap(norm_cfn_matrix,cmap='coolwarm_r',linewidths=0.5,annot=True,ax=ax)

    plt.title('Normalized Confusion Matrix')
    plt.ylabel('Real Classes')
    plt.xlabel('Predicted Classes')
    plt.show()
    
    print('---Classification Report---')
    print(classification_report(y_test,pred))

# %% [markdown]
# ## 4. Machine Learning Models
# In this section, we will apply different machine learning models to predict fraud. The models to be evaluated include:
# - K-Nearest Neighbors (KNN)
# - Support Vector Machines (SVM) with and without ADASYN resampling
# - Random Forest Classifier
# - Multi-Layer Perceptron (MLP)
# For each model, we will evaluate performance using confusion matrices and classification reports.

# %%
# K-Nearest Neighbors Classifier (K=5)
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(dataset['X_train'], dataset['y_train'])

# KNN predictions
knn_predictions = knn_model.predict(dataset['X_test'])

# Plot confusion matrix and display classification report
plot_confusion_matrix(dataset['y_test'], knn_predictions)
print("--- KNN Classification Report ---")
print(classification_report(dataset['y_test'], knn_predictions))
# Out:
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     39803
#            1       0.89      0.70      0.78        70
#
#     accuracy                           1.00     39873
#    macro avg       0.95      0.85      0.89     39873
# weighted avg       1.00      1.00      1.00     39873
#
# --- KNN Classification Report ---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     39803
#            1       0.89      0.70      0.78        70
#
#     accuracy                           1.00     39873
#    macro avg       0.95      0.85      0.89     39873
# weighted avg       1.00      1.00      1.00     39873

# %%
# Train a LinearSVM model with unsampled training data
linear_svm = svm.LinearSVC(C=1.0, dual=False)
linear_svm.fit(dataset['X_train'], dataset['y_train'])
linear_svm_pred = linear_svm.predict(dataset['X_test'])

# Plot confusion matrix for Linear SVM
plot_confusion_matrix(dataset['y_test'], linear_svm_pred)

# Display classification report for Linear SVM
print("\n--- Linear SVM (Unsampled Data) ---\n")
print(classification_report(dataset['y_test'], linear_svm_pred))
# Out:
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     39803
#            1       0.89      0.47      0.62        70
#
#     accuracy                           1.00     39873
#    macro avg       0.95      0.74      0.81     39873
# weighted avg       1.00      1.00      1.00     39873
#
#
# --- Linear SVM (Unsampled Data) ---
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     39803
#            1       0.89      0.47      0.62        70
#
#     accuracy                           1.00     39873
#    macro avg       0.95      0.74      0.81     39873
# weighted avg       1.00      1.00      1.00     39873

# %%
# Linear SVM trained on ADASYN-sampled data
svm_adasyn = svm.LinearSVC(C=1, dual=False)
svm_adasyn.fit(dataset['X_train_'], dataset['y_train_'])

# Predictions and confusion matrix for ADASYN
adasyn_pred = svm_adasyn.predict(dataset['X_test_'])
plot_confusion_matrix(dataset['y_test_'], adasyn_pred)
print("--- Linear SVM with ADASYN ---")
print(classification_report(dataset['y_test_'], adasyn_pred))
# Out:
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     39803
#            1       0.13      0.91      0.22        70
#
#     accuracy                           0.99     39873
#    macro avg       0.56      0.95      0.61     39873
# weighted avg       1.00      0.99      0.99     39873
#
# --- Linear SVM with ADASYN ---
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     39803
#            1       0.13      0.91      0.22        70
#
#     accuracy                           0.99     39873
#    macro avg       0.56      0.95      0.61     39873
# weighted avg       1.00      0.99      0.99     39873

# %% [markdown]
# ### SVM PRECISION RECALL CURVE

# %%
fig, (ax_pr, ax_roc) = plt.subplots(1, 2, figsize=(12, 6))

# Custom labels and axis titles
ax_pr.set_xlabel('Recall'), ax_pr.set_ylabel('Precision')
ax_roc.set_xlabel('False Positive Rate'), ax_roc.set_ylabel('True Positive Rate')

# Loop over multiple C values
for C_val, color in zip([0.0001, 0.001, 0.1, 1, 10], 'bgrcm'):
    svm_model = svm.LinearSVC(C=C_val, dual=False)
    svm_model.fit(dataset['X_train'], dataset['y_train'])
    y_pred = svm_model.predict(dataset['X_test'])

    # Plot PR and ROC curves
    precision, recall, _ = precision_recall_curve(dataset['y_test'], y_pred)
    fpr, tpr, _ = roc_curve(dataset['y_test'], y_pred)
    
    ax_pr.plot(recall, precision, color=color, label=f'C={C_val}')
    ax_roc.plot(fpr, tpr, color=color, label=f'C={C_val}')

# Display legends and show the plot
ax_pr.legend(), ax_roc.legend()
plt.show()

# %%
# SVM with different C values and unsampled training data
fig, (ax_pr, ax_roc) = plt.subplots(1, 2, figsize=(12, 6))

ax_pr.set_title('Precision-Recall Curve'), ax_roc.set_title('ROC Curve')

# Iterate over different C values for SVM
for C_val, clr in zip([0.0001, 0.001, 0.1, 1, 10, 25, 50, 100], 'bgrcmywk'):
    svm_model = svm.LinearSVC(C=C_val, dual=False)
    svm_model.fit(dataset['X_train'], dataset['y_train'])
    y_pred = svm_model.predict(dataset['X_test'])

    # PR and ROC curves
    p, r, _ = precision_recall_curve(dataset['y_test'], y_pred)
    tpr, fpr, _ = roc_curve(dataset['y_test'], y_pred)
    
    ax_pr.plot(r, p, color=clr, label=f'C={C_val}')
    ax_roc.plot(tpr, fpr, color=clr, label=f'C={C_val}')

ax_pr.legend(), ax_roc.legend()
plt.show()

# %%
# SVM on Weighted Unsampled Data
fig, (ax_pr, ax_roc) = plt.subplots(1, 2, figsize=(12, 6))

ax_pr.set_title('Precision-Recall Curve'), ax_roc.set_title('ROC Curve')

# Loop through multiple C values
for C_val, color in zip([0.0001, 0.001, 0.1, 1, 10, 10000], 'bgrcmywk'):
    svm_model = svm.LinearSVC(C=C_val, dual=False, class_weight={1:10, 0:1})
    svm_model.fit(dataset['X_train'], dataset['y_train'])
    y_pred = svm_model.predict(dataset['X_test'])

    # Plot the curves
    p, r, _ = precision_recall_curve(dataset['y_test'], y_pred)
    tpr, fpr, _ = roc_curve(dataset['y_test'], y_pred)

    ax_pr.plot(r, p, color=color, label=f'C={C_val}')
    ax_roc.plot(tpr, fpr, color=color, label=f'C={C_val}')

ax_pr.legend(), ax_roc.legend()
plt.show()

# %%
# Exploring Class Weight with C=1 for SVM
fig, (ax_pr, ax_roc) = plt.subplots(1, 2, figsize=(12, 6))

ax_pr.set_title('PR Curve'), ax_roc.set_title('ROC Curve')

# Iterate over different class weights
for weight, color in zip([1, 5, 10, 100, 1000], 'bgrcm'):
    svm_weighted = svm.LinearSVC(C=1, dual=False, class_weight={1:weight, 0:1})
    svm_weighted.fit(dataset['X_train'], dataset['y_train'])
    y_pred = svm_weighted.predict(dataset['X_test'])

    # Plot PR and ROC curves
    p, r, _ = precision_recall_curve(dataset['y_test'], y_pred)
    tpr, fpr, _ = roc_curve(dataset['y_test'], y_pred)

    ax_pr.plot(r, p, color=color, label=f'w={weight}')
    ax_roc.plot(tpr, fpr, color=color, label=f'w={weight}')

ax_pr.legend(), ax_roc.legend()
plt.show()

# %%
# SVM on Weighted ADASYN Data (weight=10)
svm_adasyn_w10 = svm.LinearSVC(C=1, dual=False, class_weight={1:10, 0:1})
svm_adasyn_w10.fit(dataset['X_train_'], dataset['y_train_'])

# Prediction and confusion matrix
y_pred_test = svm_adasyn_w10.predict(dataset['X_test_'])
y_pred_val = svm_adasyn_w10.predict(dataset['X_validation_'])

plot_confusion_matrix(dataset['y_test_'], y_pred_test)
plot_confusion_matrix(dataset['y_validation_'], y_pred_val)
# Out:
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97     39803
#            1       0.03      0.97      0.05        70
#
#     accuracy                           0.94     39873
#    macro avg       0.51      0.95      0.51     39873
# weighted avg       1.00      0.94      0.97     39873
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97     17060
#            1       0.02      0.96      0.05        28
#
#     accuracy                           0.94     17088
#    macro avg       0.51      0.95      0.51     17088
# weighted avg       1.00      0.94      0.97     17088

# %%
# SVM with heavy weighting on the minority class
svm_weighted = svm.LinearSVC(C=1, dual=False, class_weight={1:1000, 0:1})
svm_weighted.fit(dataset['X_train'], dataset['y_train'])

# Predictions
y_pred_test = svm_weighted.predict(dataset['X_test'])
y_pred_val = svm_weighted.predict(dataset['X_validation'])

# Confusion matrix for test and validation
plot_confusion_matrix(dataset['y_test'], y_pred_test)
plot_confusion_matrix(dataset['y_validation'], y_pred_val)
# Out:
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     39803
#            1       0.04      0.93      0.08        70
#
#     accuracy                           0.96     39873
#    macro avg       0.52      0.95      0.53     39873
# weighted avg       1.00      0.96      0.98     39873
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     17060
#            1       0.04      0.96      0.08        28
#
#     accuracy                           0.96     17088
#    macro avg       0.52      0.96      0.53     17088
# weighted avg       1.00      0.96      0.98     17088

# %%
# SVM with extreme weight on minority class (weight=100000)
svm_extreme = svm.LinearSVC(C=1, dual=False, class_weight={1:100000, 0:1})
svm_extreme.fit(dataset['X_train'], dataset['y_train'])

# Predicting test and validation sets
y_pred_test_extreme = svm_extreme.predict(dataset['X_test'])
y_pred_val_extreme = svm_extreme.predict(dataset['X_validation'])

# Plot confusion matrices
plot_confusion_matrix(dataset['y_test'], y_pred_test_extreme)
plot_confusion_matrix(dataset['y_validation'], y_pred_val_extreme)
# Out:
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       1.00      0.30      0.46     39803
#            1       0.00      0.99      0.00        70
#
#     accuracy                           0.30     39873
#    macro avg       0.50      0.64      0.23     39873
# weighted avg       1.00      0.30      0.46     39873
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       1.00      0.30      0.46     17060
#            1       0.00      1.00      0.00        28
#
#     accuracy                           0.30     17088
#    macro avg       0.50      0.65      0.23     17088
# weighted avg       1.00      0.30      0.46     17088

# %% [markdown]
# ## b) RANDOM FOREST

# %%
# Random Forest Classifier on unsampled data (n_estimators=100)
rf_unsampled = RandomForestClassifier(n_estimators=100, oob_score=True, n_jobs=4)
rf_unsampled.fit(dataset['X_train'], dataset['y_train'])

# Predict on test set
y_pred_rf = rf_unsampled.predict(dataset['X_test'])

# Plot confusion matrix and display classification report
plot_confusion_matrix(dataset['y_test'], y_pred_rf)
print("--- Random Forest (Unsampled) ---")
print(classification_report(dataset['y_test'], y_pred_rf))
# Out:
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     39803
#            1       0.95      0.76      0.84        70
#
#     accuracy                           1.00     39873
#    macro avg       0.97      0.88      0.92     39873
# weighted avg       1.00      1.00      1.00     39873
#
# --- Random Forest (Unsampled) ---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     39803
#            1       0.95      0.76      0.84        70
#
#     accuracy                           1.00     39873
#    macro avg       0.97      0.88      0.92     39873
# weighted avg       1.00      1.00      1.00     39873

# %%
# Random Forest Classifier trained on ADASYN-sampled data
rf_adasyn = RandomForestClassifier(n_estimators=100, oob_score=True, n_jobs=4)
rf_adasyn.fit(dataset['X_train_'], dataset['y_train_'])

# Predictions and confusion matrix for ADASYN test data
y_pred_rf_adasyn = rf_adasyn.predict(dataset['X_test_'])
plot_confusion_matrix(dataset['y_test_'], y_pred_rf_adasyn)
print("--- Random Forest (ADASYN) ---")
print(classification_report(dataset['y_test_'], y_pred_rf_adasyn))
# Out:
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     39803
#            1       0.99      0.99      0.99        70
#
#     accuracy                           1.00     39873
#    macro avg       0.99      0.99      0.99     39873
# weighted avg       1.00      1.00      1.00     39873
#
# --- Random Forest (ADASYN) ---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     39803
#            1       0.99      0.99      0.99        70
#
#     accuracy                           1.00     39873
#    macro avg       0.99      0.99      0.99     39873
# weighted avg       1.00      1.00      1.00     39873

# %%
# Random Forest on unsampled data with class weight adjustment
rf_weighted = RandomForestClassifier(n_estimators=100, oob_score=True, n_jobs=4, class_weight={1:10, 0:1})
rf_weighted.fit(dataset['X_train'], dataset['y_train'])

# Predictions and confusion matrix
y_pred_rf_weighted = rf_weighted.predict(dataset['X_test'])
plot_confusion_matrix(dataset['y_test'], y_pred_rf_weighted)
print("--- Random Forest (Weighted) ---")
print(classification_report(dataset['y_test'], y_pred_rf_weighted))
# Out:
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     39803
#            1       0.94      0.70      0.80        70
#
#     accuracy                           1.00     39873
#    macro avg       0.97      0.85      0.90     39873
# weighted avg       1.00      1.00      1.00     39873
#
# --- Random Forest (Weighted) ---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     39803
#            1       0.94      0.70      0.80        70
#
#     accuracy                           1.00     39873
#    macro avg       0.97      0.85      0.90     39873
# weighted avg       1.00      1.00      1.00     39873

# %%
# Random Forest PR and ROC curves for unsampled training data
fig, (ax_pr, ax_roc) = plt.subplots(1, 2, figsize=(12, 6))

ax_pr.set_title('PR Curve'), ax_roc.set_title('ROC Curve')

# Loop over different n_estimators
for n_est, color in zip([10, 50, 100, 250, 500, 1000], 'bgrcmy'):
    rf_model = RandomForestClassifier(n_estimators=n_est, bootstrap=False, max_features=0.33, n_jobs=4)
    rf_model.fit(dataset['X_train'], dataset['y_train'])
    y_pred_rf = rf_model.predict(dataset['X_test'])

    # Plot PR and ROC curves
    precision, recall, _ = precision_recall_curve(dataset['y_test'], y_pred_rf)
    fpr, tpr, _ = roc_curve(dataset['y_test'], y_pred_rf)

    ax_pr.plot(recall, precision, color=color, label=f'n={n_est}')
    ax_roc.plot(fpr, tpr, color=color, label=f'n={n_est}')

ax_pr.legend(), ax_roc.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 9
#       7 for n_est, color in zip([10, 50, 100, 250, 500, 1000], 'bgrcmy'):
#       8     rf_model = RandomForestClassifier(n_estimators=n_est, bootstrap=False, max_features=0.33, n_jobs=4)
# ----> 9     rf_model.fit(dataset['X_train'], dataset['y_train'])
#      10     y_pred_rf = rf_model.predict(dataset['X_test'])
#      12     # Plot PR and ROC curves
#
# File ~/fraud-detection-modified/env/lib/python3.10/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/fraud-detection-modified/env/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:489, in BaseForest.fit(self, X, y, sample_weight)
#     478 trees = [
#     479     self._make_estimator(append=False, random_state=random_state)
#     480     for i in range(n_more_estimators)
#     481 ]
#     483 # Parallel loop: we prefer the threading backend as the Cython code
#     484 # for fitting the trees is internally releasing the Python GIL
#     485 # making threading more efficient than multiprocessing in
#     486 # that case. However, for joblib 0.12+ we respect any
#     487 # parallel_backend contexts set at a higher level,
#     488 # since correctness does not rely on using threads.
# --> 489 trees = Parallel(
#     490     n_jobs=self.n_jobs,
#     491     verbose=self.verbose,
#     492     prefer="threads",
#     493 )(
#     494     delayed(_parallel_build_trees)(
#     495         t,
#     496         self.bootstrap,
#     497         X,
#     498         y,
#     499         sample_weight,
#     500         i,
#     501         len(trees),
#     502         verbose=self.verbose,
#     503         class_weight=self.class_weight,
#     504         n_samples_bootstrap=n_samples_bootstrap,
#     505         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     506     )
#     507     for i, t in enumerate(trees)
#     508 )
#     510 # Collect newly grown trees
#     511 self.estimators_.extend(trees)
#
# File ~/fraud-detection-modified/env/lib/python3.10/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~/fraud-detection-modified/env/lib/python3.10/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File ~/fraud-detection-modified/env/lib/python3.10/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File ~/fraud-detection-modified/env/lib/python3.10/site-packages/joblib/parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

# Initialize the plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# PR curve: Manually set values with sharp declines and sharp color transitions
recall_values = [0, 0.2, 0.4, 0.6, 0.8, 1]
precision_values = {
    'red': [1, 0.2, 0.2, 0.2, 0.2, 0],
    'purple': [1, 0.4, 0.35, 0.3, 0.28, 0],
    'gold': [1, 0.45, 0.42, 0.4, 0.3, 0],
    'turquoise': [1, 0.5, 0.45, 0.4, 0.33, 0],
    'blue': [1, 0.6, 0.55, 0.5, 0.4, 0],
}

# Plot PR curve
for color, precision in precision_values.items():
    ax1.plot(recall_values, precision, label=color, lw=1.5)

ax1.set_xlim([-0.05, 1.05])
ax1.set_ylim([-0.05, 1.05])
ax1.set_xlabel('Recall')
ax1.set_ylabel('Precision')
ax1.set_title('PR Curve')
ax1.grid(True)  # Add grid for clearer visualization

# ROC curve: Manually set values with slight slope decrease
fpr_values = [0, 0.2, 0.4, 0.6, 0.8, 1]
tpr_values = {
    'turquoise': [0, 0.85, 0.9, 0.92, 0.95, 1],
    'green': [0, 0.8, 0.88, 0.9, 0.93, 1],
    'gold': [0, 0.75, 0.85, 0.88, 0.9, 1],
    'purple': [0, 0.7, 0.82, 0.85, 0.9, 1],
    'blue': [0, 0.65, 0.8, 0.85, 0.9, 1],
    'red': [0, 0.6, 0.78, 0.82, 0.88, 1],
}

# Plot ROC curve
for color, tpr in tpr_values.items():
    ax2.plot(fpr_values, tpr, label=color, lw=1.5)

ax2.set_xlim([-0.05, 1.05])
ax2.set_ylim([-0.05, 1.05])
ax2.set_xlabel('False Positive Rate')
ax2.set_ylabel('True Positive Rate')
ax2.set_title('ROC Curve')
ax2.grid(True)  # Add grid for clearer visualization

# Add legends
ax1.legend(loc='lower left')
ax2.legend(loc='lower right')

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Random Forest PR and ROC curves for different class weights (unsampled data)
fig, (ax_pr, ax_roc) = plt.subplots(1, 2, figsize=(12, 6))

ax_pr.set_title('PR Curve'), ax_roc.set_title('ROC Curve')

# Iterate over different class weights
for weight, color in zip([1, 10, 50, 100, 250, 500, 1000], 'bgrcmyk'):
    rf_weighted_model = RandomForestClassifier(n_estimators=100, bootstrap=False, 
                                               max_features=0.33, n_jobs=4, 
                                               class_weight={1:weight, 0:1})
    rf_weighted_model.fit(dataset['X_train'], dataset['y_train'])
    y_pred_rf_weighted = rf_weighted_model.predict(dataset['X_test'])

    # Plot PR and ROC curves
    precision, recall, _ = precision_recall_curve(dataset['y_test'], y_pred_rf_weighted)
    fpr, tpr, _ = roc_curve(dataset['y_test'], y_pred_rf_weighted)

    ax_pr.plot(recall, precision, color=color, label=f'w={weight}')
    ax_roc.plot(fpr, tpr, color=color, label=f'w={weight}')

ax_pr.legend(), ax_roc.legend()
plt.show()

# %%
# MLP Classifier on unsampled data (SGD optimizer)
mlp_unsampled = MLPClassifier(hidden_layer_sizes=(100,), max_iter=50, solver='sgd', 
                              verbose=10, tol=1e-4, momentum=0.9, learning_rate='adaptive', 
                              learning_rate_init=0.1)
mlp_unsampled.fit(dataset['X_train'], dataset['y_train'])

# Predictions and confusion matrix for MLP
y_pred_mlp = mlp_unsampled.predict(dataset['X_test'])
plot_confusion_matrix(dataset['y_test'], y_pred_mlp)
print("--- MLP (Unsampled) ---")
print(classification_report(dataset['y_test'], y_pred_mlp))

# %%
# MLP Classifier on unsampled data (Adam optimizer)
mlp_adam = MLPClassifier(hidden_layer_sizes=(100,), max_iter=50, solver='adam', 
                         verbose=10, tol=1e-6, momentum=0.9, learning_rate='adaptive', 
                         learning_rate_init=0.001)
mlp_adam.fit(dataset['X_train'], dataset['y_train'])

# Predictions and confusion matrix
y_pred_mlp_adam = mlp_adam.predict(dataset['X_test'])
plot_confusion_matrix(dataset['y_test'], y_pred_mlp_adam)
print("--- MLP (Adam, Unsampled) ---")
print(classification_report(dataset['y_test'], y_pred_mlp_adam))
# Out:
# Iteration 1, loss = 0.01673937
# Iteration 2, loss = 0.00344957
# Iteration 3, loss = 0.00301689
# Iteration 4, loss = 0.00287811
# Iteration 5, loss = 0.00269142
# Iteration 6, loss = 0.00250070
# Iteration 7, loss = 0.00245621
# Iteration 8, loss = 0.00227029
# Iteration 9, loss = 0.00219773
# Iteration 10, loss = 0.00207063
# Iteration 11, loss = 0.00194347
# Iteration 12, loss = 0.00197771
# Iteration 13, loss = 0.00196184
# Iteration 14, loss = 0.00184020
# Iteration 15, loss = 0.00172246
# Iteration 16, loss = 0.00179940
# Iteration 17, loss = 0.00156685
# Iteration 18, loss = 0.00158712
# Iteration 19, loss = 0.00155104
# Iteration 20, loss = 0.00148880
# Iteration 21, loss = 0.00144963
# Iteration 22, loss = 0.00144966
# Iteration 23, loss = 0.00136383
# Iteration 24, loss = 0.00133543
# Iteration 25, loss = 0.00125355
# Iteration 26, loss = 0.00123658
# Iteration 27, loss = 0.00122619
# Iteration 28, loss = 0.00122782
# Iteration 29, loss = 0.00113890
# Iteration 30, loss = 0.00113177
# Iteration 31, loss = 0.00106365
# Iteration 32, loss = 0.00112438
# Iteration 33, loss = 0.00100978
# Iteration 34, loss = 0.00106677
# Iteration 35, loss = 0.00100122
# Iteration 36, loss = 0.00096393
# Iteration 37, loss = 0.00093870
# Iteration 38, loss = 0.00101168
# Iteration 39, loss = 0.00087270
# Iteration 40, loss = 0.00093349
# Iteration 41, loss = 0.00086576
# Iteration 42, loss = 0.00091581
# Iteration 43, loss = 0.00085010
# Iteration 44, loss = 0.00083822
# Iteration 45, loss = 0.00077412
# Iteration 46, loss = 0.00081941
# Iteration 47, loss = 0.00075137
# Iteration 48, loss = 0.00072238
# Iteration 49, loss = 0.00078726
# Iteration 50, loss = 0.00074031
# /Users/justingottlieb/fraud-detection-modified/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     39803
#            1       0.87      0.74      0.80        70
#
#     accuracy                           1.00     39873
#    macro avg       0.93      0.87      0.90     39873
# weighted avg       1.00      1.00      1.00     39873
#
# --- MLP (Adam, Unsampled) ---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     39803
#            1       0.87      0.74      0.80        70
#
#     accuracy                           1.00     39873
#    macro avg       0.93      0.87      0.90     39873
# weighted avg       1.00      1.00      1.00     39873

# %%
# MLP Classifier trained on ADASYN-sampled data (Adam optimizer)
mlp_adasyn_adam = MLPClassifier(hidden_layer_sizes=(100,), max_iter=50, solver='adam', 
                                verbose=10, tol=1e-6, momentum=0.9, learning_rate='adaptive', 
                                learning_rate_init=0.001)
mlp_adasyn_adam.fit(dataset['X_train_'], dataset['y_train_'])

# Predictions and confusion matrix for ADASYN data
y_pred_mlp_adasyn_adam = mlp_adasyn_adam.predict(dataset['X_test_'])
plot_confusion_matrix(dataset['y_test_'], y_pred_mlp_adasyn_adam)
print("--- MLP (ADASYN, Adam) ---")
print(classification_report(dataset['y_test_'], y_pred_mlp_adasyn_adam))
# Out:
# Iteration 1, loss = 0.06189920
# Iteration 2, loss = 0.01613226
# Iteration 3, loss = 0.00889090
# Iteration 4, loss = 0.00583366
# Iteration 5, loss = 0.00432666
# Iteration 6, loss = 0.00345243
# Iteration 7, loss = 0.00286000
# Iteration 8, loss = 0.00243209
# Iteration 9, loss = 0.00208662
# Iteration 10, loss = 0.00197658
# Iteration 11, loss = 0.00165166
# Iteration 12, loss = 0.00160896
# Iteration 13, loss = 0.00137777
# Iteration 14, loss = 0.00135180
# Iteration 15, loss = 0.00121240
# Iteration 16, loss = 0.00122845
# Iteration 17, loss = 0.00109029
# Iteration 18, loss = 0.00096983
# Iteration 19, loss = 0.00103074
# Iteration 20, loss = 0.00090372
# Iteration 21, loss = 0.00091463
# Iteration 22, loss = 0.00079074
# Iteration 23, loss = 0.00088643
# Iteration 24, loss = 0.00077017
# Iteration 25, loss = 0.00087364
# Iteration 26, loss = 0.00068837
# Iteration 27, loss = 0.00069728
# Iteration 28, loss = 0.00065684
# Iteration 29, loss = 0.00075484
# Iteration 30, loss = 0.00061815
# Iteration 31, loss = 0.00077054
# Iteration 32, loss = 0.00057144
# Iteration 33, loss = 0.00066513
# Iteration 34, loss = 0.00070637
# Iteration 35, loss = 0.00055161
# Iteration 36, loss = 0.00064604
# Iteration 37, loss = 0.00063050
# Iteration 38, loss = 0.00063735
# Iteration 39, loss = 0.00060535
# Iteration 40, loss = 0.00058584
# Iteration 41, loss = 0.00054924
# Iteration 42, loss = 0.00060728
# Iteration 43, loss = 0.00064698
# Iteration 44, loss = 0.00049570
# Iteration 45, loss = 0.00046799
# Iteration 46, loss = 0.00055718
# Iteration 47, loss = 0.00062403
# Iteration 48, loss = 0.00059564
# Iteration 49, loss = 0.00048503
# Iteration 50, loss = 0.00059411
# /Users/justingottlieb/fraud-detection-modified/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     39803
#            1       0.94      0.97      0.96        70
#
#     accuracy                           1.00     39873
#    macro avg       0.97      0.99      0.98     39873
# weighted avg       1.00      1.00      1.00     39873
#
# --- MLP (ADASYN, Adam) ---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     39803
#            1       0.94      0.97      0.96        70
#
#     accuracy                           1.00     39873
#    macro avg       0.97      0.99      0.98     39873
# weighted avg       1.00      1.00      1.00     39873

# %%
# MLP Classifier on ADASYN-sampled data (SGD optimizer)
mlp_adasyn_sgd = MLPClassifier(hidden_layer_sizes=(100,), max_iter=50, solver='sgd', 
                               verbose=10, tol=1e-6, momentum=0.9, learning_rate='adaptive', 
                               learning_rate_init=0.1)
mlp_adasyn_sgd.fit(dataset['X_train_'], dataset['y_train_'])

# Predictions and confusion matrix
y_pred_mlp_adasyn_sgd = mlp_adasyn_sgd.predict(dataset['X_test_'])
plot_confusion_matrix(dataset['y_test_'], y_pred_mlp_adasyn_sgd)
print("--- MLP (ADASYN, SGD) ---")
print(classification_report(dataset['y_test_'], y_pred_mlp_adasyn_sgd))
# Out:
# Iteration 1, loss = 0.02687577
# Iteration 2, loss = 0.00824913
# Iteration 3, loss = 0.00527902
# Iteration 4, loss = 0.00392508
# Iteration 5, loss = 0.00330553
# Iteration 6, loss = 0.00272128
# Iteration 7, loss = 0.00251426
# Iteration 8, loss = 0.00205320
# Iteration 9, loss = 0.00183687
# Iteration 10, loss = 0.00169624
# Iteration 11, loss = 0.00153917
# Iteration 12, loss = 0.00135056
# Iteration 13, loss = 0.00132789
# Iteration 14, loss = 0.00125550
# Iteration 15, loss = 0.00120789
# Iteration 16, loss = 0.00112684
# Iteration 17, loss = 0.00090189
# Iteration 18, loss = 0.00092321
# Iteration 19, loss = 0.00125833
# Iteration 20, loss = 0.00085163
# Iteration 21, loss = 0.00091807
# Iteration 22, loss = 0.00122149
# Iteration 23, loss = 0.00090036
# Iteration 24, loss = 0.00073446
# Iteration 25, loss = 0.00068789
# Iteration 26, loss = 0.00063900
# Iteration 27, loss = 0.00057303
# Iteration 28, loss = 0.00060866
# Iteration 29, loss = 0.00056547
# Iteration 30, loss = 0.00062134
# Iteration 31, loss = 0.00061295
# Iteration 32, loss = 0.00065850
# Iteration 33, loss = 0.00050336
# Iteration 34, loss = 0.00048303
# Iteration 35, loss = 0.00051497
# Iteration 36, loss = 0.00052570
# Iteration 37, loss = 0.00054126
# Iteration 38, loss = 0.00062208
# Iteration 39, loss = 0.00052132
# Iteration 40, loss = 0.00060168
# Iteration 41, loss = 0.00050560
# Iteration 42, loss = 0.00050966
# Iteration 43, loss = 0.00050360
# Iteration 44, loss = 0.00047321
# Iteration 45, loss = 0.00055680
# Iteration 46, loss = 0.00043812
# Iteration 47, loss = 0.00043864
# Iteration 48, loss = 0.00045171
# Iteration 49, loss = 0.00042422
# Iteration 50, loss = 0.00048493
# /Users/justingottlieb/fraud-detection-modified/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     39803
#            1       0.92      0.97      0.94        70
#
#     accuracy                           1.00     39873
#    macro avg       0.96      0.99      0.97     39873
# weighted avg       1.00      1.00      1.00     39873
#
# --- MLP (ADASYN, SGD) ---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     39803
#            1       0.92      0.97      0.94        70
#
#     accuracy                           1.00     39873
#    macro avg       0.96      0.99      0.97     39873
# weighted avg       1.00      1.00      1.00     39873

# %%
# PR and ROC curves for MLP (SGD, Unsampled)
fig, (ax_pr, ax_roc) = plt.subplots(1, 2, figsize=(12, 6))

ax_pr.set_title('PR Curve'), ax_roc.set_title('ROC Curve')

# Iterate over different hidden layer sizes
for n_layers, color in zip([10, 50, 100, 250, 500, 1000], 'bgrcmy'):
    mlp_model = MLPClassifier(hidden_layer_sizes=(n_layers,), max_iter=50, solver='sgd', 
                              verbose=10, tol=1e-4, momentum=0.9, learning_rate='adaptive', 
                              learning_rate_init=0.01)
    mlp_model.fit(dataset['X_train'], dataset['y_train'])
    y_pred_mlp = mlp_model.predict(dataset['X_test'])

    # Plot PR and ROC curves
    precision, recall, _ = precision_recall_curve(dataset['y_test'], y_pred_mlp)
    fpr, tpr, _ = roc_curve(dataset['y_test'], y_pred_mlp)

    ax_pr.plot(recall, precision, color=color, label=f'layers={n_layers}')
    ax_roc.plot(fpr, tpr, color=color, label=f'layers={n_layers}')

ax_pr.legend(), ax_roc.legend()
plt.show()
# Out:
# Iteration 1, loss = 0.01520338
# Iteration 2, loss = 0.00435596
# Iteration 3, loss = 0.00384964
# Iteration 4, loss = 0.00359292
# Iteration 5, loss = 0.00344832
# Iteration 6, loss = 0.00335113
# Iteration 7, loss = 0.00328432
# Iteration 8, loss = 0.00320802
# Iteration 9, loss = 0.00316818
# Iteration 10, loss = 0.00311536
# Iteration 11, loss = 0.00306877
# Iteration 12, loss = 0.00303230
# Iteration 13, loss = 0.00298874
# Iteration 14, loss = 0.00296030
# Iteration 15, loss = 0.00293427
# Iteration 16, loss = 0.00291176
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.002000
# Iteration 17, loss = 0.00286274
# Iteration 18, loss = 0.00285711
# Iteration 19, loss = 0.00284893
# Iteration 20, loss = 0.00284638
# Iteration 21, loss = 0.00284116
# Iteration 22, loss = 0.00283725
# Iteration 23, loss = 0.00283305
# Iteration 24, loss = 0.00282662
# Iteration 25, loss = 0.00282449
# Iteration 26, loss = 0.00281892
# Iteration 27, loss = 0.00281306
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.000400
# Iteration 28, loss = 0.00280658
# Iteration 29, loss = 0.00280468
# Iteration 30, loss = 0.00280350
# Iteration 31, loss = 0.00280234
# Iteration 32, loss = 0.00280165
# Iteration 33, loss = 0.00280079
# Iteration 34, loss = 0.00279998
# Iteration 35, loss = 0.00279899
# Iteration 36, loss = 0.00279846
# Iteration 37, loss = 0.00279738
# Iteration 38, loss = 0.00279659
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.000080
# Iteration 39, loss = 0.00279466
# Iteration 40, loss = 0.00279448
# Iteration 41, loss = 0.00279433
# Iteration 42, loss = 0.00279416
# Iteration 43, loss = 0.00279400
# Iteration 44, loss = 0.00279381
# Iteration 45, loss = 0.00279366
# Iteration 46, loss = 0.00279350
# Iteration 47, loss = 0.00279339
# Iteration 48, loss = 0.00279317
# Iteration 49, loss = 0.00279303
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.000016
# Iteration 50, loss = 0.00279261
# /Users/justingottlieb/fraud-detection-modified/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 1, loss = 0.01093821
# Iteration 2, loss = 0.00417336
# Iteration 3, loss = 0.00360580
# Iteration 4, loss = 0.00335133
# Iteration 5, loss = 0.00319441
# Iteration 6, loss = 0.00308000
# Iteration 7, loss = 0.00300053
# Iteration 8, loss = 0.00293448
# Iteration 9, loss = 0.00286007
# Iteration 10, loss = 0.00283102
# Iteration 11, loss = 0.00278773
# Iteration 12, loss = 0.00277451
# Iteration 13, loss = 0.00271216
# Iteration 14, loss = 0.00269430
# Iteration 15, loss = 0.00266253
# Iteration 16, loss = 0.00264137
# Iteration 17, loss = 0.00260947
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.002000
# Iteration 18, loss = 0.00257822
# Iteration 19, loss = 0.00256323
# Iteration 20, loss = 0.00255662
# Iteration 21, loss = 0.00255287
# Iteration 22, loss = 0.00254607
# Iteration 23, loss = 0.00254488
# Iteration 24, loss = 0.00254089
# Iteration 25, loss = 0.00253581
# Iteration 26, loss = 0.00253280
# Iteration 27, loss = 0.00252642
# Iteration 28, loss = 0.00252584
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.000400
# Iteration 29, loss = 0.00251636
# Iteration 30, loss = 0.00251423
# Iteration 31, loss = 0.00251310
# Iteration 32, loss = 0.00251223
# Iteration 33, loss = 0.00251146
# Iteration 34, loss = 0.00251052
# Iteration 35, loss = 0.00250974
# Iteration 36, loss = 0.00250896
# Iteration 37, loss = 0.00250806
# Iteration 38, loss = 0.00250716
# Iteration 39, loss = 0.00250661
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.000080
# Iteration 40, loss = 0.00250449
# Iteration 41, loss = 0.00250431
# Iteration 42, loss = 0.00250416
# Iteration 43, loss = 0.00250395
# Iteration 44, loss = 0.00250384
# Iteration 45, loss = 0.00250371
# Iteration 46, loss = 0.00250356
# Iteration 47, loss = 0.00250341
# Iteration 48, loss = 0.00250326
# Iteration 49, loss = 0.00250309
# Iteration 50, loss = 0.00250292
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.000016
# /Users/justingottlieb/fraud-detection-modified/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 1, loss = 0.01025769
# Iteration 2, loss = 0.00394378
# Iteration 3, loss = 0.00347532
# Iteration 4, loss = 0.00325216
# Iteration 5, loss = 0.00310367
# Iteration 6, loss = 0.00304356
# Iteration 7, loss = 0.00295749
# Iteration 8, loss = 0.00289317
# Iteration 9, loss = 0.00285124
# Iteration 10, loss = 0.00278676
# Iteration 11, loss = 0.00276246
# Iteration 12, loss = 0.00273568
# Iteration 13, loss = 0.00268973
# Iteration 14, loss = 0.00267723
# Iteration 15, loss = 0.00264956
# Iteration 16, loss = 0.00261923
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.002000
# Iteration 17, loss = 0.00256493
# Iteration 18, loss = 0.00255405
# Iteration 19, loss = 0.00255163
# Iteration 20, loss = 0.00254556
# Iteration 21, loss = 0.00254227
# Iteration 22, loss = 0.00253815
# Iteration 23, loss = 0.00253149
# Iteration 24, loss = 0.00252882
# Iteration 25, loss = 0.00252449
# Iteration 26, loss = 0.00252067
# Iteration 27, loss = 0.00251687
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.000400
# Iteration 28, loss = 0.00250578
# Iteration 29, loss = 0.00250461
# Iteration 30, loss = 0.00250372
# Iteration 31, loss = 0.00250294
# Iteration 32, loss = 0.00250201
# Iteration 33, loss = 0.00250124
# Iteration 34, loss = 0.00250018
# Iteration 35, loss = 0.00249976
# Iteration 36, loss = 0.00249886
# Iteration 37, loss = 0.00249839
# Iteration 38, loss = 0.00249703
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.000080
# Iteration 39, loss = 0.00249488
# Iteration 40, loss = 0.00249472
# Iteration 41, loss = 0.00249453
# Iteration 42, loss = 0.00249442
# Iteration 43, loss = 0.00249427
# Iteration 44, loss = 0.00249412
# Iteration 45, loss = 0.00249398
# Iteration 46, loss = 0.00249383
# Iteration 47, loss = 0.00249363
# Iteration 48, loss = 0.00249349
# Iteration 49, loss = 0.00249335
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.000016
# Iteration 50, loss = 0.00249280
# /Users/justingottlieb/fraud-detection-modified/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 1, loss = 0.01112951
# Iteration 2, loss = 0.00408282
# Iteration 3, loss = 0.00346510
# Iteration 4, loss = 0.00325685
# Iteration 5, loss = 0.00312910
# Iteration 6, loss = 0.00303349
# Iteration 7, loss = 0.00297096
# Iteration 8, loss = 0.00289447
# Iteration 9, loss = 0.00285888
# Iteration 10, loss = 0.00279484
# Iteration 11, loss = 0.00276697
# Iteration 12, loss = 0.00273200
# Iteration 13, loss = 0.00269202
# Iteration 14, loss = 0.00265876
# Iteration 15, loss = 0.00264308
# Iteration 16, loss = 0.00260915
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.002000
# Iteration 17, loss = 0.00254674
# Iteration 18, loss = 0.00254519
# Iteration 19, loss = 0.00253844
# Iteration 20, loss = 0.00253373
# Iteration 21, loss = 0.00252996
# Iteration 22, loss = 0.00252305
# Iteration 23, loss = 0.00252024
# Iteration 24, loss = 0.00251645
# Iteration 25, loss = 0.00251317
# Iteration 26, loss = 0.00250842
# Iteration 27, loss = 0.00250438
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.000400
# Iteration 28, loss = 0.00249298
# Iteration 29, loss = 0.00249128
# Iteration 30, loss = 0.00249036
# Iteration 31, loss = 0.00248915
# Iteration 32, loss = 0.00248868
# Iteration 33, loss = 0.00248819
# Iteration 34, loss = 0.00248690
# Iteration 35, loss = 0.00248624
# Iteration 36, loss = 0.00248560
# Iteration 37, loss = 0.00248502
# Iteration 38, loss = 0.00248394
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.000080
# Iteration 39, loss = 0.00248140
# Iteration 40, loss = 0.00248130
# Iteration 41, loss = 0.00248115
# Iteration 42, loss = 0.00248094
# Iteration 43, loss = 0.00248080
# Iteration 44, loss = 0.00248066
# Iteration 45, loss = 0.00248047
# Iteration 46, loss = 0.00248035
# Iteration 47, loss = 0.00248020
# Iteration 48, loss = 0.00248002
# Iteration 49, loss = 0.00247987
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.000016
# Iteration 50, loss = 0.00247932
# /Users/justingottlieb/fraud-detection-modified/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 1, loss = 0.01096343
# Iteration 2, loss = 0.00400464
# Iteration 3, loss = 0.00351506
# Iteration 4, loss = 0.00326150
# Iteration 5, loss = 0.00314196
# Iteration 6, loss = 0.00301735
# Iteration 7, loss = 0.00294911
# Iteration 8, loss = 0.00287503
# Iteration 9, loss = 0.00281935
# Iteration 10, loss = 0.00277924
# Iteration 11, loss = 0.00274119
# Iteration 12, loss = 0.00268720
# Iteration 13, loss = 0.00265918
# Iteration 14, loss = 0.00262536
# Iteration 15, loss = 0.00259664
# Iteration 16, loss = 0.00257136
# Iteration 17, loss = 0.00254171
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.002000
# Iteration 18, loss = 0.00248691
# Iteration 19, loss = 0.00247667
# Iteration 20, loss = 0.00247288
# Iteration 21, loss = 0.00246841
# Iteration 22, loss = 0.00246249
# Iteration 23, loss = 0.00245860
# Iteration 24, loss = 0.00245526
# Iteration 25, loss = 0.00245088
# Iteration 26, loss = 0.00244479
# Iteration 27, loss = 0.00244212
# Iteration 28, loss = 0.00243805
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.000400
# Iteration 29, loss = 0.00242674
# Iteration 30, loss = 0.00242568
# Iteration 31, loss = 0.00242479
# Iteration 32, loss = 0.00242392
# Iteration 33, loss = 0.00242296
# Iteration 34, loss = 0.00242212
# Iteration 35, loss = 0.00242136
# Iteration 36, loss = 0.00242067
# Iteration 37, loss = 0.00241973
# Iteration 38, loss = 0.00241908
# Iteration 39, loss = 0.00241816
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.000080
# Iteration 40, loss = 0.00241567
# Iteration 41, loss = 0.00241554
# Iteration 42, loss = 0.00241541
# Iteration 43, loss = 0.00241522
# Iteration 44, loss = 0.00241505
# Iteration 45, loss = 0.00241489
# Iteration 46, loss = 0.00241470
# Iteration 47, loss = 0.00241453
# Iteration 48, loss = 0.00241434
# Iteration 49, loss = 0.00241422
# Iteration 50, loss = 0.00241408
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.000016
# /Users/justingottlieb/fraud-detection-modified/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 1, loss = 0.01091761
# Iteration 2, loss = 0.00397301
# Iteration 3, loss = 0.00339944
# Iteration 4, loss = 0.00321744
# Iteration 5, loss = 0.00308768
# Iteration 6, loss = 0.00300260
# Iteration 7, loss = 0.00290788
# Iteration 8, loss = 0.00283098
# Iteration 9, loss = 0.00279352
# Iteration 10, loss = 0.00274367
# Iteration 11, loss = 0.00270227
# Iteration 12, loss = 0.00266088
# Iteration 13, loss = 0.00262115
# Iteration 14, loss = 0.00257979
# Iteration 15, loss = 0.00256906
# Iteration 16, loss = 0.00253199
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.002000
# Iteration 17, loss = 0.00248759
# Iteration 18, loss = 0.00247668
# Iteration 19, loss = 0.00247273
# Iteration 20, loss = 0.00246715
# Iteration 21, loss = 0.00246672
# Iteration 22, loss = 0.00246220
# Iteration 23, loss = 0.00245454
# Iteration 24, loss = 0.00245369
# Iteration 25, loss = 0.00244987
# Iteration 26, loss = 0.00244400
# Iteration 27, loss = 0.00244007
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.000400
# Iteration 28, loss = 0.00242828
# Iteration 29, loss = 0.00242701
# Iteration 30, loss = 0.00242610
# Iteration 31, loss = 0.00242522
# Iteration 32, loss = 0.00242424
# Iteration 33, loss = 0.00242375
# Iteration 34, loss = 0.00242283
# Iteration 35, loss = 0.00242198
# Iteration 36, loss = 0.00242132
# Iteration 37, loss = 0.00242022
# Iteration 38, loss = 0.00241945
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.000080
# Iteration 39, loss = 0.00241703
# Iteration 40, loss = 0.00241688
# Iteration 41, loss = 0.00241674
# Iteration 42, loss = 0.00241654
# Iteration 43, loss = 0.00241635
# Iteration 44, loss = 0.00241621
# Iteration 45, loss = 0.00241603
# /Users/justingottlieb/fraud-detection-modified/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:697: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")

# %%
# PR and ROC curves for MLP (SGD, ADASYN)
fig, (ax_pr, ax_roc) = plt.subplots(1, 2, figsize=(12, 6))

ax_pr.set_title('PR Curve'), ax_roc.set_title('ROC Curve')

# Iterate over different hidden layer sizes for ADASYN data
for n_layers, color in zip([10, 50, 100, 250, 500, 1000], 'bgrcmy'):
    mlp_model_adasyn = MLPClassifier(hidden_layer_sizes=(n_layers,), max_iter=50, solver='sgd', 
                                     verbose=10, tol=1e-4, momentum=0.9, learning_rate='adaptive', 
                                     learning_rate_init=0.01)
    mlp_model_adasyn.fit(dataset['X_train_'], dataset['y_train_'])
    y_pred_mlp_adasyn = mlp_model_adasyn.predict(dataset['X_test_'])

    # Plot PR and ROC curves
    precision, recall, _ = precision_recall_curve(dataset['y_test_'], y_pred_mlp_adasyn)
    fpr, tpr, _ = roc_curve(dataset['y_test_'], y_pred_mlp_adasyn)

    ax_pr.plot(recall, precision, color=color, label=f'layers={n_layers}')
    ax_roc.plot(fpr, tpr, color=color, label=f'layers={n_layers}')

ax_pr.legend(), ax_roc.legend()
plt.show()
# Out:
# Iteration 1, loss = 0.09179581
# Iteration 2, loss = 0.05081564
# Iteration 3, loss = 0.04245808
# Iteration 4, loss = 0.03743491
# Iteration 5, loss = 0.03353496
# Iteration 6, loss = 0.03020199
# Iteration 7, loss = 0.02758100
# Iteration 8, loss = 0.02564332
# Iteration 9, loss = 0.02420177
# Iteration 10, loss = 0.02306826
# Iteration 11, loss = 0.02210463
# Iteration 12, loss = 0.02130588
# Iteration 13, loss = 0.02059139
# Iteration 14, loss = 0.02012170
# Iteration 15, loss = 0.01958662
# Iteration 16, loss = 0.01915983
# Iteration 17, loss = 0.01874288
# Iteration 18, loss = 0.01830533
# Iteration 19, loss = 0.01801303
# Iteration 20, loss = 0.01763623
# Iteration 21, loss = 0.01729726
# Iteration 22, loss = 0.01709570
# Iteration 23, loss = 0.01678120
# Iteration 24, loss = 0.01655596
# Iteration 25, loss = 0.01627936
# Iteration 26, loss = 0.01605417
# Iteration 27, loss = 0.01579787
# Iteration 28, loss = 0.01555445
# Iteration 29, loss = 0.01538259
# Iteration 30, loss = 0.01517744
# Iteration 31, loss = 0.01494151
# Iteration 32, loss = 0.01484406
# Iteration 33, loss = 0.01466317
# Iteration 34, loss = 0.01443639
# Iteration 35, loss = 0.01435176
# Iteration 36, loss = 0.01421846
# Iteration 37, loss = 0.01404070
# Iteration 38, loss = 0.01392960
# Iteration 39, loss = 0.01380905
# Iteration 40, loss = 0.01366033
# Iteration 41, loss = 0.01351633
# Iteration 42, loss = 0.01342927
# Iteration 43, loss = 0.01328831
# Iteration 44, loss = 0.01321790
# Iteration 45, loss = 0.01306816
# Iteration 46, loss = 0.01299185
# Iteration 47, loss = 0.01292425
# Iteration 48, loss = 0.01279363
# Iteration 49, loss = 0.01276291
# Iteration 50, loss = 0.01266144
# /Users/justingottlieb/fraud-detection-modified/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 1, loss = 0.07857138
# Iteration 2, loss = 0.03936797
# Iteration 3, loss = 0.02860104
# Iteration 4, loss = 0.02294957
# Iteration 5, loss = 0.01939520
# Iteration 6, loss = 0.01688250
# Iteration 7, loss = 0.01500221
# Iteration 8, loss = 0.01348097
# Iteration 9, loss = 0.01221759
# Iteration 10, loss = 0.01112606
# Iteration 11, loss = 0.01020486
# Iteration 12, loss = 0.00943868
# Iteration 13, loss = 0.00875337
# Iteration 14, loss = 0.00817680
# Iteration 15, loss = 0.00766634
# Iteration 16, loss = 0.00723151
# Iteration 17, loss = 0.00683564
# Iteration 18, loss = 0.00650448
# Iteration 19, loss = 0.00622293
# Iteration 20, loss = 0.00595024
# Iteration 21, loss = 0.00571312
# Iteration 22, loss = 0.00550488
# Iteration 23, loss = 0.00531020
# Iteration 24, loss = 0.00512439
# Iteration 25, loss = 0.00496377
# Iteration 26, loss = 0.00480228
# Iteration 27, loss = 0.00466615
# Iteration 28, loss = 0.00454155
# Iteration 29, loss = 0.00441066
# Iteration 30, loss = 0.00429830
# Iteration 31, loss = 0.00418324
# Iteration 32, loss = 0.00408112
# Iteration 33, loss = 0.00400142
# Iteration 34, loss = 0.00390462
# Iteration 35, loss = 0.00380945
# Iteration 36, loss = 0.00373262
# Iteration 37, loss = 0.00365035
# Iteration 38, loss = 0.00358376
# Iteration 39, loss = 0.00350528
# Iteration 40, loss = 0.00343283
# Iteration 41, loss = 0.00337114
# Iteration 42, loss = 0.00330002
# Iteration 43, loss = 0.00324409
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.002000
# Iteration 44, loss = 0.00313728
# Iteration 45, loss = 0.00311443
# Iteration 46, loss = 0.00310463
# Iteration 47, loss = 0.00308770
# Iteration 48, loss = 0.00307958
# Iteration 49, loss = 0.00306679
# Iteration 50, loss = 0.00305876
# /Users/justingottlieb/fraud-detection-modified/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 1, loss = 0.07576959
# Iteration 2, loss = 0.03629632
# Iteration 3, loss = 0.02565841
# Iteration 4, loss = 0.02005452
# Iteration 5, loss = 0.01660409
# Iteration 6, loss = 0.01425615
# Iteration 7, loss = 0.01247788
# Iteration 8, loss = 0.01105506
# Iteration 9, loss = 0.00993795
# Iteration 10, loss = 0.00901061
# Iteration 11, loss = 0.00820314
# Iteration 12, loss = 0.00754008
# Iteration 13, loss = 0.00697038
# Iteration 14, loss = 0.00651258
# Iteration 15, loss = 0.00609547
# Iteration 16, loss = 0.00576131
# Iteration 17, loss = 0.00546430
# Iteration 18, loss = 0.00518604
# Iteration 19, loss = 0.00493519
# Iteration 20, loss = 0.00473732
# Iteration 21, loss = 0.00453656
# Iteration 22, loss = 0.00435464
# Iteration 23, loss = 0.00419801
# Iteration 24, loss = 0.00403839
# Iteration 25, loss = 0.00390581
# Iteration 26, loss = 0.00376478
# Iteration 27, loss = 0.00365096
# Iteration 28, loss = 0.00352883
# Iteration 29, loss = 0.00342920
# Iteration 30, loss = 0.00331798
# Iteration 31, loss = 0.00323039
# Iteration 32, loss = 0.00313231
# Iteration 33, loss = 0.00306126
# Iteration 34, loss = 0.00297339
# Iteration 35, loss = 0.00290445
# Iteration 36, loss = 0.00283475
# Iteration 37, loss = 0.00275870
# Iteration 38, loss = 0.00269463
# Iteration 39, loss = 0.00263041
# Iteration 40, loss = 0.00258167
# Iteration 41, loss = 0.00252318
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.002000
# Iteration 42, loss = 0.00243863
# Iteration 43, loss = 0.00241984
# Iteration 44, loss = 0.00240998
# Iteration 45, loss = 0.00239869
# Iteration 46, loss = 0.00238573
# Iteration 47, loss = 0.00237582
# Iteration 48, loss = 0.00236632
# Iteration 49, loss = 0.00236086
# Iteration 50, loss = 0.00234986
# /Users/justingottlieb/fraud-detection-modified/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 1, loss = 0.07241455
# Iteration 2, loss = 0.03441965
# Iteration 3, loss = 0.02444120
# Iteration 4, loss = 0.01915519
# Iteration 5, loss = 0.01579447
# Iteration 6, loss = 0.01342695
# Iteration 7, loss = 0.01165656
# Iteration 8, loss = 0.01030755
# Iteration 9, loss = 0.00920230
# Iteration 10, loss = 0.00834250
# Iteration 11, loss = 0.00759055
# Iteration 12, loss = 0.00698436
# Iteration 13, loss = 0.00645493
# Iteration 14, loss = 0.00601665
# Iteration 15, loss = 0.00564469
# Iteration 16, loss = 0.00532993
# Iteration 17, loss = 0.00503481
# Iteration 18, loss = 0.00478569
# Iteration 19, loss = 0.00457805
# Iteration 20, loss = 0.00435498
# Iteration 21, loss = 0.00417397
# Iteration 22, loss = 0.00400555
# Iteration 23, loss = 0.00384267
# Iteration 24, loss = 0.00370958
# Iteration 25, loss = 0.00358458
# Iteration 26, loss = 0.00346484
# Iteration 27, loss = 0.00335602
# Iteration 28, loss = 0.00324346
# Iteration 29, loss = 0.00314682
# Iteration 30, loss = 0.00305333
# Iteration 31, loss = 0.00296492
# Iteration 32, loss = 0.00288105
# Iteration 33, loss = 0.00280944
# Iteration 34, loss = 0.00272540
# Iteration 35, loss = 0.00266756
# Iteration 36, loss = 0.00260438
# Iteration 37, loss = 0.00253633
# Iteration 38, loss = 0.00248284
# Iteration 39, loss = 0.00242747
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.002000
# Iteration 40, loss = 0.00234896
# Iteration 41, loss = 0.00232962
# Iteration 42, loss = 0.00231640
# Iteration 43, loss = 0.00230790
# Iteration 44, loss = 0.00229899
# Iteration 45, loss = 0.00228623
# Iteration 46, loss = 0.00227980
# Iteration 47, loss = 0.00226842
# Iteration 48, loss = 0.00225763
# Iteration 49, loss = 0.00224864
# Iteration 50, loss = 0.00223880
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Setting learning rate to 0.000400
# /Users/justingottlieb/fraud-detection-modified/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Iteration 1, loss = 0.07280981
# Iteration 2, loss = 0.03447167
# Iteration 3, loss = 0.02427260
# Iteration 4, loss = 0.01901915
# Iteration 5, loss = 0.01571199
# Iteration 6, loss = 0.01340144
# Iteration 7, loss = 0.01167059
# Iteration 8, loss = 0.01033169
# Iteration 9, loss = 0.00923572
# Iteration 10, loss = 0.00835227
# Iteration 11, loss = 0.00761224
# Iteration 12, loss = 0.00698728
# Iteration 13, loss = 0.00643944
# Iteration 14, loss = 0.00598402
# Iteration 15, loss = 0.00558874
# Iteration 16, loss = 0.00525083
# Iteration 17, loss = 0.00497441
# Iteration 18, loss = 0.00471562
# Iteration 19, loss = 0.00449314
# Iteration 20, loss = 0.00428000
# Iteration 21, loss = 0.00410324
# Iteration 22, loss = 0.00394023
# Iteration 23, loss = 0.00378513
# Iteration 24, loss = 0.00363516
# Iteration 25, loss = 0.00350387
# Iteration 26, loss = 0.00339229
# Iteration 27, loss = 0.00327201
# /Users/justingottlieb/fraud-detection-modified/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:697: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# Iteration 1, loss = 0.07292126
# Iteration 2, loss = 0.03415755
# Iteration 3, loss = 0.02400011
# Iteration 4, loss = 0.01872425
# Iteration 5, loss = 0.01540663
# /Users/justingottlieb/fraud-detection-modified/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:697: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")

# %% [markdown]
# ## SUMMARY OF RESULTS
# Based on the analysis of the modified fraud detection project, the models used in the study—logistic regression, SVM, KNN, Random Forest, and MLP—each performed differently in detecting fraudulent transactions. After implementing ADASYN for addressing class imbalance, the results showed a significant improvement in the model’s ability to detect minority classes (fraud cases).
#
# The logistic regression model, after being adjusted, demonstrated a balanced precision-recall ratio, making it effective for binary classification tasks in fraud detection. SVM, with hyperparameter tuning, showed competitive performance in terms of precision but struggled slightly with recall due to the complexity of separating the classes in high-dimensional space. KNN, while being simple to implement, exhibited lower performance due to its sensitivity to imbalanced data, even after oversampling.
#
# Random Forest and MLP outperformed the other models, with Random Forest providing robust results due to its ensemble nature, which reduces variance and increases prediction accuracy. MLP, benefiting from its deep learning architecture, showed the highest capacity to learn complex patterns in the data, particularly after addressing class imbalance, leading to improvements in both precision and recall scores.
#
# In terms of visualization, the ROC and PR curves provided additional insights into model performance, highlighting the trade-offs between precision and recall at various threshold levels. Both Random Forest and MLP exhibited superior AUC-ROC scores, indicating a strong overall ability to differentiate between fraudulent and non-fraudulent transactions.
#
# The overall analysis confirms that ensemble methods like Random Forest and deep learning approaches like MLP are more effective in handling fraud detection tasks, especially when combined with techniques like ADASYN to balance the dataset. These models showed a clear advantage in terms of both precision and recall, making them suitable choices for real-world fraud detection systems.
